# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#                 padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Week 8 - Project</h1>
# </div>

# %% [markdown]
# #### Write a python script that:
# - scrapes the following webpage:
# https://en.wikipedia.org/wiki/Template:COVID-19_pandemic_data
# - parses the html for the table of covid data
# - fills missing values with `None`
# - calculates the death and recovery rate for each  country
# - writes the data in csv format to a file called:`{your-name}-covid-report.csv`
#
# Your csv file should contain the following "header" (and corresponding data):
#
# ```csv
# country,cases,deaths,recoveries,death_rate,recovery_rate
#
# ```
#
# Please ask for clarification if needed.

# %%
from bs4 import BeautifulSoup
import requests
import csv
# writes the data in csv format to a file called:{your-name}-covid-report.csv
url = "https://en.wikipedia.org/wiki/Template:COVID-19_pandemic_data"
def CovidData(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text)
    rows = soup.find('tbody').findAll('tr')[2:235]
    th_td_list = []
    for row in rows:
        th = row.findAll('th')[1]
        tds = row.findAll('td')[:-1]
        th_td_data_row = []
        th_td_data_row.append(th.text.strip().split('[')[0])
        for td in tds:
            td_text = td.text.strip()
            td_text = ''.join(td_text.split(','))
            if td_text == 'No data':
                td_text = None
            elif '.' in td_text:
                count_digits = len(td_text) - td_text.index('.') - 1
                td_text = int(''.join('9.492'.split('.'))) / 10 ** count_digits
            else:
                td_text = int(td_text)
            th_td_data_row.append(td_text)
        th_td_list.append(th_td_data_row)
    for row_list in th_td_list[:-1]:
        death_rate = "%.3f" % (row_list[2] / row_list[1])
        try:
            recovery_rate = "%.3f" % (row_list[3] / row_list[1])
        except:
            recovery_rate = row_list[3]
        row_list.append(death_rate)
        row_list.append(recovery_rate)
    return th_td_list

CovidData(url)

# def data_to_csv(url):
#     with open("clariza_mayo_covid-report.csv", "w") as csvfile:
#         file = csv.writer(csvfile)
#         file.writerow(["Country","Cases","Deaths","Recoveries","Death Rate","Recovery Rate"])
#         file.writerows(CovidData(url))
        
# data_to_csv(url)
# Out:
# [['United States', 10810305, 247646, 5885568, '0.023', '0.544'],
#  ['India', 8728795, 128668, 8115580, '0.015', '0.930'],
#  ['Brazil', 5811699, 164855, 5267567, '0.028', '0.906'],
#  ['France', 1922504, 43892, 137155, '0.023', '0.071'],
#  ['Russia', 1903253, 32834, 1425529, '0.017', '0.749'],
#  ['Spain', 1458591, 40769, None, '0.028', None],
#  ['United Kingdom', 1344356, 51766, None, '0.039', None],
#  ['Argentina', 1296365, 35045, 1110464, '0.027', '0.857'],
#  ['Colombia', 1182697, 33669, 1089340, '0.028', '0.921'],
#  ['Italy', 1144552, 44683, 411434, '0.039', '0.359'],
#  ['Mexico', 997393, 97624, 741340, '0.098', '0.743'],
#  ['Peru', 932650, 35106, 858388, '0.038', '0.920'],
#  ['Germany', 772822, 12281, 481610, '0.016', '0.623'],
#  ['Iran', 749525, 41034, 552747, '0.055', '0.737'],
#  ['South Africa', 746945, 20153, 692177, '0.027', '0.927'],
#  ['Poland', 691118, 10045, 282215, '0.015', '0.408'],
#  ['Chile', 528030, 14738, 503540, '0.028', '0.954'],
#  ['Ukraine', 525176, 9508, 238811, '0.018', '0.455'],
#  ['Belgium', 520393, 13891, None, '0.027', None],
#  ['Iraq', 514496, 11580, 441856, '0.023', '0.859'],
#  ['Indonesia', 463007, 15148, 388094, '0.033', '0.838'],
#  ['Czech Republic', 454030, 5926, 316352, '0.013', '0.697'],
#  ['Netherlands', 436544, 8358, None, '0.019', None],
#  ['Bangladesh', 430496, 6173, 347849, '0.014', '0.808'],
#  ['Turkey', 411055, 11418, 351102, '0.028', '0.854'],
#  ['Philippines', 406337, 7791, 363068, '0.019', '0.894'],
#  ['Pakistan', 354461, 7109, 322414, '0.020', '0.910'],
#  ['Romania', 353185, 8813, 239051, '0.025', '0.677'],
#  ['Saudi Arabia', 352950, 5641, 339947, '0.016', '0.963'],
#  ['Israel', 322695, 2716, 312131, '0.008', '0.967'],
#  ['Canada', 288899, 10848, 231649, '0.038', '0.802'],
#  ['Morocco', 282336, 4631, 229160, '0.016', '0.812'],
#  ['Switzerland', 257135, 2960, 130600, '0.012', '0.508'],
#  ['Portugal', 211255, 3305, 122517, '0.016', '0.580'],
#  ['Nepal', 208299, 1215, 170632, '0.006', '0.819'],
#  ['Austria', 198291, 1746, 119415, '0.009', '0.602'],
#  ['Ecuador', 178674, 12977, 154956, '0.073', '0.867'],
#  ['Sweden', 177355, 6164, None, '0.035', None],
#  ['United Arab Emirates', 147961, 528, 141883, '0.004', '0.959'],
#  ['Panama', 144477, 2856, 123229, '0.020', '0.853'],
#  ['Bolivia', 143069, 8835, 116505, '0.062', '0.814'],
#  ['Jordan', 141305, 1704, None, '0.012', None],
#  ['Qatar', 135570, 234, 132577, '0.002', '0.978'],
#  ['Kuwait', 135650, 833, 126344, '0.006', '0.931'],
#  ['Dominican Republic', 132554, 2280, 109268, '0.017', '0.824'],
#  ['Hungary', 136723, 2990, 31126, '0.022', '0.228'],
#  ['Costa Rica', 122123, 1537, 74868, '0.013', '0.613'],
#  ['Oman', 119442, 1326, 110050, '0.011', '0.921'],
#  ['Kazakhstan', 119129, 1899, 108958, '0.016', '0.915'],
#  ['Japan', 114983, 1880, 101989, '0.016', '0.887'],
#  ['Armenia', 114383, 1697, 72116, '0.015', '0.630'],
#  ['Guatemala', 114123, 3880, 103685, '0.034', '0.909'],
#  ['Belarus', 112870, 1039, 94337, '0.009', '0.836'],
#  ['Egypt', 110319, 6429, 100847, '0.058', '0.914'],
#  ['Lebanon', 102607, 796, 57693, '0.008', '0.562'],
#  ['Honduras', 102079, 2820, 44236, '0.028', '0.433'],
#  ['Ethiopia', 101757, 1558, 63571, '0.015', '0.625'],
#  ['Venezuela', 96140, 841, 91141, '0.009', '0.948'],
#  ['Bulgaria', 94937, 2055, 28269, '0.022', '0.298'],
#  ['Moldova', 88772, 2006, 69526, '0.023', '0.783'],
#  ['China', 86325, 4634, 81303, '0.054', '0.942'],
#  ['Bahrain', 84349, 332, 82038, '0.004', '0.973'],
#  ['Slovakia', 83796, 491, 26439, '0.006', '0.316'],
#  ['Croatia', 81844, 1006, 63748, '0.012', '0.779'],
#  ['Serbia', 81086, 989, None, '0.012', None],
#  ['Tunisia', 77668, 2209, 52912, '0.028', '0.681'],
#  ['Azerbaijan', 73429, 946, 54049, '0.013', '0.736'],
#  ['Georgia', 73154, 636, 55511, '0.009', '0.759'],
#  ['Libya', 72628, 995, 43259, '0.014', '0.596'],
#  ['Bosnia and Herzegovina', 70900, 1857, 35361, '0.026', '0.499'],
#  ['Paraguay', 70392, 1556, 50514, '0.022', '0.718'],
#  ['Uzbekistan', 69754, 594, 66886, '0.009', '0.959'],
#  ['Greece', 69675, 997, None, '0.014', None],
#  ['Kenya', 68193, 1228, 44872, '0.018', '0.658'],
#  ['Myanmar', 68011, 1552, 51362, '0.023', '0.755'],
#  ['Ireland', 67099, 1972, 24000, '0.029', '0.358'],
#  ['Algeria', 65975, 2124, 43779, '0.032', '0.664'],
#  ['Kyrgyzstan', 65454, 1195, 56307, '0.018', '0.860'],
#  ['Nigeria', 64884, 1163, 60936, '0.018', '0.939'],
#  ['Palestine', 61514, 548, 53367, '0.009', '0.868'],
#  ['Denmark', 60000, 756, 45705, '0.013', '0.762'],
#  ['Singapore', 58114, 28, 58008, '0.000', '0.998'],
#  ['Slovenia', 52385, 724, None, '0.014', None],
#  ['Ghana', 50018, 320, 48179, '0.006', '0.963'],
#  ['Malaysia', 46209, 306, 33772, '0.007', '0.731'],
#  ['North Macedonia', 44898, 1263, 26289, '0.028', '0.586'],
#  ['Afghanistan', 43035, 1605, 35067, '0.037', '0.815'],
#  ['Puerto Rico', 40574, 914, None, '0.023', None],
#  ['El Salvador', 36195, 1033, 32487, '0.029', '0.898'],
#  ['Lithuania', 33387, 266, 7697, '0.008', '0.231'],
#  ['South Korea', 28338, 492, 25636, '0.017', '0.905'],
#  ['Norway', 27916, 294, 11863, '0.011', '0.425'],
#  ['Kosovo', 27851, 797, 16862, '0.029', '0.605'],
#  ['Australia', 27702, 907, 25468, '0.033', '0.919'],
#  ['Albania', 27233, 612, 12767, '0.022', '0.469'],
#  ['Montenegro', 26109, 377, 16904, '0.014', '0.647'],
#  ['Luxembourg', 25931, 219, 15428, '0.008', '0.595'],
#  ['Cameroon', 22421, 433, 20510, '0.019', '0.915'],
#  ['Ivory Coast', 20899, 127, 20599, '0.006', '0.986'],
#  ['Finland', 18858, 369, 14000, '0.020', '0.742'],
#  ['Madagascar', 17223, 249, 16516, '0.014', '0.959'],
#  ['Zambia', 17093, 350, 16134, '0.020', '0.944'],
#  ['Sri Lanka', 16405, 53, 11324, '0.003', '0.690'],
#  ['Senegal', 15755, 326, 15400, '0.021', '0.977'],
#  ['Uganda', 15402, 144, 8038, '0.009', '0.522'],
#  ['Sudan', 14401, 1116, 9535, '0.077', '0.662'],
#  ['Mozambique', 14227, 110, 12238, '0.008', '0.860'],
#  ['Namibia', 13372, 138, 11620, '0.010', '0.869'],
#  ['Angola', 13228, 317, 6326, '0.024', '0.478'],
#  ['Guinea', 12537, 74, 10899, '0.006', '0.869'],
#  ['Maldives', 12112, 41, 11244, '0.003', '0.928'],
#  ['French Polynesia', 11706, 53, 4842, '0.005', '0.414'],
#  ['DR Congo', 11692, 318, 10983, '0.027', '0.939'],
#  ['Tajikistan', 11534, 85, 10894, '0.007', '0.945'],
#  ['Latvia', 9836, 116, 1515, '0.012', '0.154'],
#  ['Cape Verde', 9741, 102, 9076, '0.010', '0.932'],
#  ['Jamaica', 9723, 227, 5168, '0.023', '0.532'],
#  ['Haiti', 9168, 232, 7701, '0.025', '0.840'],
#  ['Gabon', 9062, 58, 8939, '0.006', '0.986'],
#  ['Zimbabwe', 8765, 257, 8090, '0.029', '0.923'],
#  ['Donetsk PR', 8568, 769, 4115, '0.090', '0.480'],
#  ['Mauritania', 7932, 165, 7513, '0.021', '0.947'],
#  ['Malta', 7917, 95, 5702, '0.012', '0.720'],
#  ['Cuba', 7541, 131, 6965, '0.017', '0.924'],
#  ['Bahamas', 7163, 155, 5282, '0.022', '0.737'],
#  ['Estonia', 7412, 80, 4708, '0.011', '0.635'],
#  ['Cyprus', 6853, 28, 2021, '0.004', '0.295'],
#  ['Botswana', 6820, 27, 5559, '0.004', '0.815'],
#  ['Syria', 6552, 337, 2609, '0.051', '0.398'],
#  ['Eswatini', 6076, 118, 5756, '0.019', '0.947'],
#  ['Trinidad and Tobago', 5980, 111, 5343, '0.019', '0.893'],
#  ['Malawi', 5962, 185, 5372, '0.031', '0.901'],
#  ['Guam', 5924, 93, 3942, '0.016', '0.665'],
#  ['Andorra', 5725, 75, 4675, '0.013', '0.817'],
#  ['Nicaragua', 5661, 158, 4225, '0.028', '0.746'],
#  ['Djibouti', 5641, 61, 5509, '0.011', '0.977'],
#  ['Congo', 5515, 92, 3887, '0.017', '0.705'],
#  ['Hong Kong', 5437, 108, 5177, '0.020', '0.952'],
#  ['Rwanda', 5362, 42, 4993, '0.008', '0.931'],
#  ['Suriname', 5268, 114, 5131, '0.022', '0.974'],
#  ['Iceland', 5170, 25, 4698, '0.005', '0.909'],
#  ['Equatorial Guinea', 5104, 85, 4973, '0.017', '0.974'],
#  ['Central African Republic', 4866, 62, 1924, '0.013', '0.395'],
#  ['Guyana', 4724, 138, 3688, '0.029', '0.781'],
#  ['Aruba', 4650, 43, 4511, '0.009', '0.970'],
#  ['Belize', 4596, 75, 2513, '0.016', '0.547'],
#  ['Somalia', 4301, 107, 3330, '0.025', '0.774'],
#  ['Uruguay', 3883, 64, 3135, '0.016', '0.807'],
#  ['Thailand', 3866, 60, 3707, '0.016', '0.959'],
#  ['Mali', 3806, 139, 2926, '0.037', '0.769'],
#  ['The Gambia', 3698, 122, 3557, '0.033', '0.962'],
#  ['South Sudan', 2980, 59, 1290, '0.020', '0.433'],
#  ['Benin', 2844, 43, 2515, '0.015', '0.884'],
#  ['Togo', 2627, 60, 1856, '0.023', '0.707'],
#  ['Burkina Faso', 2609, 68, 2413, '0.026', '0.925'],
#  ['Abkhazia', 2579, 27, 1167, '0.010', '0.453'],
#  ['Guinea-Bissau', 2419, 43, 2255, '0.018', '0.932'],
#  ['Sierra Leone', 2389, 74, 1816, '0.031', '0.760'],
#  ['Yemen', 2071, 605, 1394, '0.292', '0.673'],
#  ['Lesotho', 2041, 44, 1056, '0.022', '0.517'],
#  ['Luhansk PR', 1669, 121, 1391, '0.072', '0.833'],
#  ['New Zealand', 1642, 25, 1562, '0.015', '0.951'],
#  ['Chad', 1551, 99, 1394, '0.064', '0.899'],
#  ['Liberia', 1452, 82, 1311, '0.056', '0.903'],
#  ['U.S. Virgin Islands', 1405, 23, 1345, '0.016', '0.957'],
#  ['Curaçao', 1261, 2, 913, '0.002', '0.724'],
#  ['Niger', 1246, 69, 1144, '0.055', '0.918'],
#  ['Vietnam', 1226, 35, 1087, '0.029', '0.887'],
#  ['Somaliland', 1188, 37, 972, '0.031', '0.818'],
#  ['San Marino', 1114, 42, 789, '0.038', '0.708'],
#  ['USS Theodore Roosevelt', 1102, 1, 751, '0.001', '0.681'],
#  ['Charles de Gaulle', 1081, 0, 0, '0.000', '0.000'],
#  ['Northern Cyprus', 976, 5, 916, '0.005', '0.939'],
#  ['São Tomé and Príncipe', 962, 16, 912, '0.017', '0.948'],
#  ['Sint Maarten', 923, 24, 835, '0.026', '0.905'],
#  ['Gibraltar', 887, 1, 742, '0.001', '0.837'],
#  ['Liechtenstein', 801, 4, 565, '0.005', '0.705'],
#  ['Turks and Caicos Islands', 716, 6, 695, '0.008', '0.971'],
#  ['Diamond Princess', 712, 14, 653, '0.020', '0.917'],
#  ['Jersey', 672, 32, 534, '0.048', '0.795'],
#  ['Taiwan', 600, 7, 535, '0.012', '0.892'],
#  ['Papua New Guinea', 599, 7, 585, '0.012', '0.977'],
#  ['Burundi', 589, 1, 511, '0.002', '0.868'],
#  ['Comoros', 563, 7, 532, '0.012', '0.945'],
#  ['Faroe Islands', 497, 0, 494, '0.000', '0.994'],
#  ['Eritrea', 491, 0, 438, '0.000', '0.892'],
#  ['Monaco', 490, 2, 369, '0.004', '0.753'],
#  ['Mauritius', 453, 10, 416, '0.022', '0.918'],
#  ['Artsakh', 404, 2, 337, '0.005', '0.834'],
#  ['Bhutan', 369, 0, 345, '0.000', '0.935'],
#  ['Mongolia', 368, 0, 31, '0.000', '0.084'],
#  ['Isle of Man', 359, 25, 324, '0.070', '0.903'],
#  ['Cambodia', 301, 0, 288, '0.000', '0.957'],
#  ['Guernsey', 282, 13, 253, '0.046', '0.897'],
#  ['Cayman Islands', 250, 1, 236, '0.004', '0.944'],
#  ['Barbados', 249, 7, 234, '0.028', '0.940'],
#  ['Bermuda', 214, 9, 182, '0.042', '0.850'],
#  ['Saint Lucia', 160, 2, 46, '0.013', '0.287'],
#  ['Seychelles', 153, 0, 149, '0.000', '0.974'],
#  ['Costa Atlantica', 148, 0, 148, '0.000', '1.000'],
#  ['Brunei', 148, 3, 143, '0.020', '0.966'],
#  ['Bonaire', 134, 3, 126, '0.022', '0.940'],
#  ['Greg Mortimer', 128, 1, None, '0.008', None],
#  ['Antigua and Barbuda', 128, 3, 117, '0.023', '0.914'],
#  ['Northern Mariana Islands', 100, 2, 19, '0.020', '0.190'],
#  ['South Ossetia', 90, 0, 90, '0.000', '1.000'],
#  ['Saint Vincent', 78, 0, 76, '0.000', '0.974'],
#  ['British Virgin Islands', 71, 1, 70, '0.014', '0.986'],
#  ['Dominica', 68, 0, 41, '0.000', '0.603'],
#  ['Macau', 46, 0, 46, '0.000', '1.000'],
#  ['Fiji', 35, 2, 32, '0.057', '0.914'],
#  ['East Timor', 30, 0, 29, '0.000', '0.967'],
#  ['Sahrawi Arab DR', 28, 2, 26, '0.071', '0.929'],
#  ['Grenada', 28, 0, 24, '0.000', '0.857'],
#  ['New Caledonia', 28, 0, 28, '0.000', '1.000'],
#  ['Vatican City', 27, 0, 15, '0.000', '0.556'],
#  ['Laos', 24, 0, 23, '0.000', '0.958'],
#  ['Saint Kitts and Nevis', 19, 0, 19, '0.000', '1.000'],
#  ['Greenland', 17, 0, 17, '0.000', '1.000'],
#  ['Saint Pierre and Miquelon', 16, 0, 12, '0.000', '0.750'],
#  ['Sint Eustatius', 14, 0, 4, '0.000', '0.286'],
#  ['Falkland Islands', 13, 0, 13, '0.000', '1.000'],
#  ['Montserrat', 13, 1, 12, '0.077', '0.923'],
#  ['MS Zaandam', 13, 4, None, '0.308', None],
#  ['Solomon Islands', 13, 0, 4, '0.000', '0.308'],
#  ['Coral Princess', 12, 3, None, '0.250', None],
#  ['HNLMS Dolfijn', 8, 0, 8, '0.000', '1.000'],
#  ['SeaDream I', 6, 0, None, '0.000', None],
#  ['Saba', 5, 0, 5, '0.000', '1.000'],
#  ['Anguilla', 3, 0, 3, '0.000', '1.000'],
#  ['Marshall Islands', 2, 0, 2, '0.000', '1.000'],
#  ['Wallis and Futuna', 1, 0, 1, '0.000', '1.000'],
#  ['Vanuatu', 1, 0, 0]]

# %%
#how to convert a string into a integer and mantain the same amount of digits after decimal point
# number = '9.492'
# if '.' in number:
#     count_digits = len(number) - number.index('.') - 1
# new_number = int(''.join('9.492'.split('.'))) / 10 ** count_digits

# %%
#how to remove commas in a string so we can then turn it into an integer
# ''.join([elem for elem in '10,460,302' if elem != ','])
