# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#                 padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Week 8 - Project</h1>
# </div>

# %% [markdown]
# #### Write a python script that:
# - scrapes the following webpage:
# https://en.wikipedia.org/wiki/Template:COVID-19_pandemic_data
# - parses the html for the table of covid data
# - fills missing values with `None`
# - calculates the death and recovery rate for each  country
# - writes the data in csv format to a file called:`{your-name}-covid-report.csv`
#
# Your csv file should contain the following "header" (and corresponding data):
#
# ```csv
# country,cases,deaths,recoveries,death_rate,recovery_rate
#
# ```
#
# Please ask for clarification if needed.

# %%
from bs4 import BeautifulSoup
import requests

def CovidData(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content)
    return soup

CovidData("https://en.wikipedia.org/wiki/Template:COVID-19_pandemic_data")
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Template:COVID-19 pandemic data - Wikipedia</title>
# ...

# %%
from bs4 import BeautifulSoup
import requests

def CovidData(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content)
    table = soup.find("table", attrs = {'class':"cast_list"})
    return table
# # getting the table body (rows and columns)
#     table_body = table.find('tbody')
#     rows = table.find_all('tr')
#     data = []
#     for row in rows[1:]:
#         cols = row.find_all('td')
#         col = cols[0].find_all('a')  
#         cols = [ele.text.strip() for ele in cols]
#         if tmp := [ele for ele in cols if ele and ele != "..."]:
#             new_line = tmp[1].find("\n")
#             tmp[1] = tmp[1][0:new_line]
#             data.append(tmp[0:2]) # Get rid of empty values. This returns a list
#     return {x[0]: x[1] for x in data} #make a dictionary as it's being returned to change the formatting
# #     return [{"Actor": x[0], "Character": x[1]} for x in data]

print(CovidData("https://en.wikipedia.org/wiki/Template:COVID-19_pandemic_data"))
# Out:
# None
