# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1 >Week 17 Project</h1>
# </div>

# %% [markdown]
# Complete the following parts:
#
# ### Part 1
# In the 20×20 grid below, four numbers along a diagonal line have been marked in red.
#
# <p class="monospace center">
# 08 02 22 97 38 15 00 40 00 75 04 05 07 78 52 12 50 77 91 08<br />
# 49 49 99 40 17 81 18 57 60 87 17 40 98 43 69 48 04 56 62 00<br />
# 81 49 31 73 55 79 14 29 93 71 40 67 53 88 30 03 49 13 36 65<br />
# 52 70 95 23 04 60 11 42 69 24 68 56 01 32 56 71 37 02 36 91<br />
# 22 31 16 71 51 67 63 89 41 92 36 54 22 40 40 28 66 33 13 80<br />
# 24 47 32 60 99 03 45 02 44 75 33 53 78 36 84 20 35 17 12 50<br />
# 32 98 81 28 64 23 67 10 <span style="color:red;"><b>26</b></span> 38 40 67 59 54 70 66 18 38 64 70<br />
# 67 26 20 68 02 62 12 20 95 <span  style="color:red;"><b>63</b></span> 94 39 63 08 40 91 66 49 94 21<br />
# 24 55 58 05 66 73 99 26 97 17 <span  style="color:red;"><b>78</b></span> 78 96 83 14 88 34 89 63 72<br />
# 21 36 23 09 75 00 76 44 20 45 35 <span  style="color:red;"><b>14</b></span> 00 61 33 97 34 31 33 95<br />
# 78 17 53 28 22 75 31 67 15 94 03 80 04 62 16 14 09 53 56 92<br />
# 16 39 05 42 96 35 31 47 55 58 88 24 00 17 54 24 36 29 85 57<br />
# 86 56 00 48 35 71 89 07 05 44 44 37 44 60 21 58 51 54 17 58<br />
# 19 80 81 68 05 94 47 69 28 73 92 13 86 52 17 77 04 89 55 40<br />
# 04 52 08 83 97 35 99 16 07 97 57 32 16 26 26 79 33 27 98 66<br />
# 88 36 68 87 57 62 20 72 03 46 33 67 46 55 12 32 63 93 53 69<br />
# 04 42 16 73 38 25 39 11 24 94 72 18 08 46 29 32 40 62 76 36<br />
# 20 69 36 41 72 30 23 88 34 62 99 69 82 67 59 85 74 04 36 16<br />
# 20 73 35 29 78 31 90 01 74 31 49 71 48 86 81 16 23 57 05 54<br />
# 01 70 54 71 83 51 54 69 16 92 33 48 61 43 52 01 89 19 67 48<br /></p>
# <p>The product of these numbers is 26 × 63 × 78 × 14 = 1788696.</p>
# <p>What is the greatest product of four adjacent numbers in the same direction (up, down, left, right, or diagonally) in the 20×20 grid?</p>
#
# Use numpy or pandas as needed.

# %%
import numpy as np
import pandas as pd

#lst of list or panda
#figure out what is the 4th element in 
#2 for loops: one for row and one for column + 2 more for lops to go i:  8 different combination for each number:
#one for each combination

grid = \
"""
08 02 22 97 38 15 00 40 00 75 04 05 07 78 52 12 50 77 91 08
49 49 99 40 17 81 18 57 60 87 17 40 98 43 69 48 04 56 62 00
81 49 31 73 55 79 14 29 93 71 40 67 53 88 30 03 49 13 36 65
52 70 95 23 04 60 11 42 69 24 68 56 01 32 56 71 37 02 36 91
22 31 16 71 51 67 63 89 41 92 36 54 22 40 40 28 66 33 13 80
24 47 32 60 99 03 45 02 44 75 33 53 78 36 84 20 35 17 12 50
32 98 81 28 64 23 67 10 26 38 40 67 59 54 70 66 18 38 64 70
67 26 20 68 02 62 12 20 95 63 94 39 63 08 40 91 66 49 94 21
24 55 58 05 66 73 99 26 97 17 78 78 96 83 14 88 34 89 63 72
21 36 23 09 75 00 76 44 20 45 35 14 00 61 33 97 34 31 33 95
78 17 53 28 22 75 31 67 15 94 03 80 04 62 16 14 09 53 56 92
16 39 05 42 96 35 31 47 55 58 88 24 00 17 54 24 36 29 85 57
86 56 00 48 35 71 89 07 05 44 44 37 44 60 21 58 51 54 17 58
19 80 81 68 05 94 47 69 28 73 92 13 86 52 17 77 04 89 55 40
04 52 08 83 97 35 99 16 07 97 57 32 16 26 26 79 33 27 98 66
88 36 68 87 57 62 20 72 03 46 33 67 46 55 12 32 63 93 53 69
04 42 16 73 38 25 39 11 24 94 72 18 08 46 29 32 40 62 76 36
20 69 36 41 72 30 23 88 34 62 99 69 82 67 59 85 74 04 36 16
20 73 35 29 78 31 90 01 74 31 49 71 48 86 81 16 23 57 05 54
01 70 54 71 83 51 54 69 16 92 33 48 61 43 52 01 89 19 67 48
"""
def solution(grid):
    new_grid = grid.split()
    lst = [int(char) for char in new_grid]
    df =np.array(lst).reshape(20,20)
    print(df)
    largest_product = 0
    temp = 1 
    lenght = 4
    #to check product left to right
    for elem in range(20):
        for num in range(20-lenght):
            for step in range(lenght):
                temp *= df[elem][num + step]
            if temp > largest_product:
                largest_product = temp
            temp = 1
    
    #to check product up to down
    for elem in range(20-lenght):
        for num in range(20):
            for step in range(lenght):
                temp *= df[elem+step][num]
            if temp > largest_product:
                largest_product = temp
            temp = 1
    
    #to check product diagonally to the right
    for elem in range(20-lenght):
        for num in range(20-lenght):
            for step in range(lenght):
                temp *= df[elem+step][num+step]  #so it can push the number down and to the side 
            if temp > largest_product:
                largest_product = temp
            temp = 1
    
    #to check product diagonally to the left
    for elem in range(20- lenght):
        for num in range(lenght, 20):
            for step in range(lenght):
                temp *= df[elem+step][num-step]  #-k so we can go backwards
            if temp > largest_product:
                largest_product = temp
            temp = 1
    return largest_product

solution(grid)
# Out:
# [[ 8  2 22 97 38 15  0 40  0 75  4  5  7 78 52 12 50 77 91  8]
#  [49 49 99 40 17 81 18 57 60 87 17 40 98 43 69 48  4 56 62  0]
#  [81 49 31 73 55 79 14 29 93 71 40 67 53 88 30  3 49 13 36 65]
#  [52 70 95 23  4 60 11 42 69 24 68 56  1 32 56 71 37  2 36 91]
#  [22 31 16 71 51 67 63 89 41 92 36 54 22 40 40 28 66 33 13 80]
#  [24 47 32 60 99  3 45  2 44 75 33 53 78 36 84 20 35 17 12 50]
#  [32 98 81 28 64 23 67 10 26 38 40 67 59 54 70 66 18 38 64 70]
#  [67 26 20 68  2 62 12 20 95 63 94 39 63  8 40 91 66 49 94 21]
#  [24 55 58  5 66 73 99 26 97 17 78 78 96 83 14 88 34 89 63 72]
#  [21 36 23  9 75  0 76 44 20 45 35 14  0 61 33 97 34 31 33 95]
#  [78 17 53 28 22 75 31 67 15 94  3 80  4 62 16 14  9 53 56 92]
#  [16 39  5 42 96 35 31 47 55 58 88 24  0 17 54 24 36 29 85 57]
#  [86 56  0 48 35 71 89  7  5 44 44 37 44 60 21 58 51 54 17 58]
#  [19 80 81 68  5 94 47 69 28 73 92 13 86 52 17 77  4 89 55 40]
#  [ 4 52  8 83 97 35 99 16  7 97 57 32 16 26 26 79 33 27 98 66]
# ...

# %% [markdown]
# ## Part 2
#
# For this part we will use the dataset `covid_19_data.csv` located in the `../datasets` folder.

# %%
df = pd.read_csv('covid_19_data.csv')
df
# Out:
#        SNo ObservationDate                        Province/State  \
# 0        1      01/22/2020                                 Anhui
# 1        2      01/22/2020                               Beijing
# 2        3      01/22/2020                             Chongqing
# 3        4      01/22/2020                                Fujian
# 4        5      01/22/2020                                 Gansu
# ...    ...             ...                                   ...
# 4242  4243      03/08/2020                    Northern Territory
# 4243  4244      03/08/2020  Lackland, TX (From Diamond Princess)
# 4244  4245      03/08/2020                 Montgomery County, TX
# 4245  4246      03/08/2020     Omaha, NE (From Diamond Princess)
# 4246  4247      03/08/2020    Travis, CA (From Diamond Princess)
#
#       Country/Region          Last Update  Confirmed  Deaths  Recovered
# 0     Mainland China      1/22/2020 17:00        1.0     0.0        0.0
# ...

# %% [markdown]
# **1. What is the shape of this dataframe?**

# %%
df.shape  #4247 rows, 8 columns
# Out:
# (4247, 8)

# %% [markdown]
# **2. How many missing values are there? How do we find this out? Which column is problematic?**

# %%
# enter your code here
df.info()  #providence/state column doesn't have 4247 values. It only has 2749
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4247 entries, 0 to 4246
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SNo              4247 non-null   int64
#  1   ObservationDate  4247 non-null   object
#  2   Province/State   2749 non-null   object
#  3   Country/Region   4247 non-null   object
#  4   Last Update      4247 non-null   object
#  5   Confirmed        4247 non-null   float64
#  6   Deaths           4247 non-null   float64
#  7   Recovered        4247 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 265.6+ KB

# %%
#gives you all the rows that do not have providence/state
missing_values = df[df["Province/State"].isna()]
missing_values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2d3d4bfbd41c> in <module>
#       1 #gives you all the rows that do not have providence/state
# ----> 2 missing_values = df[df["Province/State"].isna()]
#       3 missing_values
#
# NameError: name 'df' is not defined

# %%
missing_values
# Out:
#        SNo ObservationDate Province/State Country/Region          Last Update  \
# 35      36      01/22/2020            NaN          Japan      1/22/2020 17:00
# 36      37      01/22/2020            NaN       Thailand      1/22/2020 17:00
# 37      38      01/22/2020            NaN    South Korea      1/22/2020 17:00
# 73      74      01/23/2020            NaN          Japan        1/23/20 17:00
# 74      75      01/23/2020            NaN       Thailand        1/23/20 17:00
# ...    ...             ...            ...            ...                  ...
# 4183  4184      03/08/2020            NaN         Serbia  2020-03-06T15:43:02
# 4184  4185      03/08/2020            NaN      Sri Lanka  2020-02-08T03:43:03
# 4185  4186      03/08/2020            NaN           Togo  2020-03-07T02:13:09
# 4239  4240      03/08/2020            NaN        Ukraine  2020-03-03T15:33:02
# 4240  4241      03/08/2020            NaN   Vatican City  2020-03-06T15:43:02
#
# ...

# %% [markdown]
# **3. In your own words, what could we do about the missing values? Should we remove rows with the missing values? Are they useful?**

# %% [raw]
# # write your answer here:
# I would keep the rows because although that column is missing values, the remaining info from the other columns like country and confirmed cases could be useful for future calculations like deaths and Recovered.
# I will replace them with unknown instead so that it doesn't affect the other data.

# %%
df.fillna("unknown", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4247 entries, 0 to 4246
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SNo              4247 non-null   int64
#  1   ObservationDate  4247 non-null   object
#  2   Province/State   4247 non-null   object
#  3   Country/Region   4247 non-null   object
#  4   Last Update      4247 non-null   object
#  5   Confirmed        4247 non-null   float64
#  6   Deaths           4247 non-null   float64
#  7   Recovered        4247 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 265.6+ KB

# %% [markdown]
# **4. Where was the first observation of more than 100+ covid cases?**

# %%
df[(df["Confirmed"] > 100)].iloc[0] #the first observation of 444 cases was made 1/22/20 in China
# Out:
# SNo                             14
# ObservationDate         01/22/2020
# Province/State               Hubei
# Country/Region      Mainland China
# Last Update        1/22/2020 17:00
# Confirmed                      444
# Deaths                          17
# Recovered                       28
# Name: 13, dtype: object

# %% [markdown]
# **5. What was the date of the first confirmed covid case in the United States?**

# %%
#Checking how United States appear in the column
def see_possible_categories(col):
    return df.groupby(col).sum()
    
see_possible_categories("Country/Region")
# Out:
#                           SNo  Confirmed  Deaths  Recovered
# Country/Region
#  Azerbaijan              2664        1.0     0.0        0.0
# Afghanistan             42823       17.0     0.0        0.0
# Algeria                 40233       91.0     0.0        0.0
# Andorra                 24901        7.0     0.0        0.0
# Argentina               21692       25.0     1.0        0.0
# ...                       ...        ...     ...        ...
# US                    2131972     2660.0    90.0      150.0
# Ukraine                 22172        6.0     0.0        0.0
# United Arab Emirates    73821      524.0     0.0      108.0
# Vatican City            11989        3.0     0.0        0.0
# Vietnam                 74949      560.0     0.0      342.0
#
# [111 rows x 4 columns]

# %%
df[(df["Country/Region"]== "US")].iloc[0]  #the first confirmed case in US was 1/22/20
# Out:
# SNo                             32
# ObservationDate         01/22/2020
# Province/State          Washington
# Country/Region                  US
# Last Update        1/22/2020 17:00
# Confirmed                        1
# Deaths                           0
# Recovered                        0
# Name: 31, dtype: object

# %% [markdown]
# **6. What caused the most amount of confirmed cases in U.S. during this period?**

# %%
#Diamond Princess
df.loc[(df['Country/Region'] == 'US')].groupby("Province/State")["Confirmed"].sum().sort_values(ascending=False).iloc[:50]
# Out:
# Province/State
# Unassigned Location (From Diamond Princess)    603.0
# King County, WA                                329.0
# Westchester County, NY                         188.0
# Santa Clara, CA                                131.0
# Snohomish County, WA                           116.0
# Los Angeles, CA                                 91.0
# San Benito, CA                                  70.0
# Santa Clara County, CA                          70.0
# Chicago, IL                                     61.0
# San Diego County, CA                            56.0
# Seattle, WA                                     43.0
# Grand Princess Cruise Ship                      42.0
# New York County, NY                             39.0
# Tempe, AZ                                       35.0
# Cook County, IL                                 35.0
# Boston, MA                                      34.0
# Madison, WI                                     33.0
# ...

# %% [markdown]
# **7. How many deaths occurred in the top 5 deadliest countries in the period of our data set?**

# %%
df.groupby("Country/Region")["Deaths"].sum().sort_values(ascending=False)[:5].sum()
# Out:
# 73999.0

# %% [markdown]
# **8. Which country had the highest number of confirmed cases but zero deaths during this period?**

# %%
df.groupby("Country/Region")[["Confirmed","Deaths"]].sum().sort_values("Deaths",ascending=False)  #Germany
# Out:
#                 Confirmed   Deaths
# Country/Region
# Mainland China  2312052.0  71199.0
# Italy             35041.0   1318.0
# Iran              30003.0   1030.0
# South Korea       58078.0    362.0
# US                 2660.0     90.0
# ...                   ...      ...
# Germany            4316.0      0.0
# Georgia              41.0      0.0
# French Guiana        10.0      0.0
# Finland             126.0      0.0
# Vietnam             560.0      0.0
#
# [111 rows x 2 columns]

# %% [markdown]
# **9. Which country had the highest percent of deaths compared to its cases during this period?**

# %%
temp_df = df.groupby("Country/Region")[["Confirmed","Deaths"]].sum().sort_values("Confirmed",ascending=False)
temp_df["Percentage D/C"] = (temp_df["Deaths"] / temp_df["Confirmed"]) *100
temp_df.sort_values("Percentage D/C",ascending=False)   #Phillippines
# Out:
#                 Confirmed  Deaths  Percentage D/C
# Country/Region
# Philippines         118.0    36.0       30.508475
# Iraq                335.0    17.0        5.074627
# San Marino          139.0     6.0        4.316547
# Argentina            25.0     1.0        4.000000
# Italy             35041.0  1318.0        3.761308
# ...                   ...     ...             ...
# Portugal             80.0     0.0        0.000000
# Ecuador              82.0     0.0        0.000000
# Algeria              91.0     0.0        0.000000
# Croatia              96.0     0.0        0.000000
#  Azerbaijan           1.0     0.0        0.000000
#
# [111 rows x 3 columns]

# %% [markdown]
# **10. What was the total number of confirmed cases by day?**

# %%
 df.groupby("ObservationDate")[["Confirmed"]].sum().sort_values("ObservationDate",ascending=True)
# Out:
#                  Confirmed
# ObservationDate
# 01/22/2020           555.0
# 01/23/2020           653.0
# 01/24/2020           941.0
# 01/25/2020          1438.0
# 01/26/2020          2118.0
# 01/27/2020          2927.0
# 01/28/2020          5578.0
# 01/29/2020          6165.0
# 01/30/2020          8235.0
# 01/31/2020          9925.0
# 02/01/2020         12038.0
# 02/02/2020         16787.0
# 02/03/2020         19881.0
# 02/04/2020         23892.0
# 02/05/2020         27636.0
# 02/06/2020         30818.0
# 02/07/2020         34392.0
# 02/08/2020         37121.0
# 02/09/2020         40151.0
# 02/10/2020         42763.0
# 02/11/2020         44803.0
# 02/12/2020         45222.0
# 02/13/2020         60370.0
# 02/14/2020         66887.0
# 02/15/2020         69032.0
# 02/16/2020         71226.0
# 02/17/2020         73260.0
# 02/18/2020         75138.0
# 02/19/2020         75641.0
# 02/20/2020         76199.0
# 02/21/2020         76843.0
# 02/22/2020         78599.0
# ...

# %% [markdown]
# **11. Can you plot a chart from this dataset?**

# %%
import matplotlib.pyplot as plt

# %%
series = df.groupby("Country/Region")["Deaths"].sum().sort_values(ascending=False).head()
plt.plot(df["ObservationDate"],
       df["Deaths"])

# %%
group = df.groupby("Country/Region")["Deaths"].sum().sort_values(ascending=False).head()
group.plot.bar()
plt.show()
